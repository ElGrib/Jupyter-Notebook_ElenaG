# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# Task 1 : Create Markdown cells

# %% [markdown]
# <H1>My Jupyter Notebook on IBM Watson Studio / Skills Network Labs</H1>

# %% [markdown]
# <b>Elena Gribneva</b> <br>
# Data Scientist

# %% [markdown]
# <i>I am interested in data science because I believe that this new discipline could solve not only problems of the modern world like climate changes, health care, biological diversity, but also to contribute for the integrating of the "good practices" in every company, small or big, organizations, ect.</i>

# %% [markdown]
# <H3> In the next cell will be demonstrated an addition of two numbers "1+1"</H3>

# %%
1+1
# Out:
# 2

# %% [markdown]
# <hr>
# <ul>
#     <li> Unordered list 1 </li>
#     <li> Unordered list 2 </li>
#     <li> Unordered list 3 </li>
# </ul>
# <hr>
# <table>
#     <tr>
#         <th>Name</th>
#         <th>Desired occupation</th>
#     </tr>
#     <tr>
#         <td>Elena Gribneva</td>
#         <td>Data Scientist</td>
#     </tr>
# </table>
# <hr>

# %% [markdown]
# <b>Exercise 2 </b> - Create a markdown cell with the title of the notebook. (1 pt)

# %% [markdown]
# <H1>My Jupyter Notebook on IBM Watson Studio / Skills Network Labs</H1>

# %% [markdown]
# <b>Exercise 3</b> - Create a markdown cell for an introduction. (1 pt)

# %% [markdown]
# <i>My name is Elena and I am interested in data science because I believe that this new discipline could solve not only problems of the modern world like climate changes, health care, biological diversity, but also to contribute for the integrating of the "good practices" in every company, small or big, organizations, ect.</i>

# %% [markdown]
# <b>Exercise 4 </b>- Create a markdown cell to list data science languages. (3 pts)

# %% [markdown]
# <ul>
#     <li> Python </li>
#     <li> R </li>
#     <li> SQL </li>
#     <li> Others:  Scala, Java, C++, and Julia are some of the most popular. Javascript, PHP, Go, Ruby, and Visual Basic </li>
# </ul>

# %% [markdown]
# <b>Exercise 5 </b> - Create a markdown cell to list data science libraries. (3 pts)

# %% [markdown]
# <ul>
#     <li> Python libraries: Scientific Computing Libraries in Python Visualization Libraries in Python High-Level Machine Learning and Deep Learning Libraries: Pandas, NumPy, Matplotlib, Seaborn, Scikit-learn, SciPy, Keras, TensorFlow,BigDL,</li>
#     <li> Experimentation: Pytorch </li>
#     <li> Apache Spark - general-purpose cluster-computing framework </li>
#     <li> Vegas is a Scala library for statistical data visualizations </li>
#     <li> ggplot2 is a popular library for data visualization in R</li>
# </ul>

# %% [markdown]
# <b>Exercise 6 </b> - Create a markdown cell with a table of Data Science tools. (3 pts)

# %% [markdown]
# <table>
#     <tr>
#         <th colspan="6">Most commonly used open source tools</th>
#     </tr>
#     <tr>
#         <td colspan="6"><b>Fully integrated Visual tools</b></td>
#     </tr>
#     <tr>
#         <td colspan="6">Fully integrated Visual tools</td>
#     </tr>
#     <tr>
#         <td colspan="6"> Data asset management</td>
#     </tr>
#     <tr>
#         <td>Data Management | </td>
#         <td>Data Integration and Transformation | </td>
#         <td>Data Visualization | </td>
#         <td>Model Building | </td>
#         <td>Model deployment | </td>
#         <td>Model monitoring and assessment</td>
#     </tr>
#     <tr>
#         <td colspan="6">Code asset management</td>
#     </tr>
#     <tr>
#         <td colspan="6">Development environments</td>
#     </tr>
# </table>

# %% [markdown]
# <b>Exercise 7 </b> - Create a markdown cell introducing arithmetic expression examples. (1 pt)

# %% [markdown]
# <H3> In the next cells will be demonstrated multiplication and addition"</H3>

# %% [markdown]
# <b>Exercise 8</b> - Create a code cell to multiply and add numbers.(2 pts)

# %%
print(2*(1+1))
# Out:
# 4

# %% [markdown]
# <b>Exercise 9 </b> - Create a code cell to convert minutes to hours. (2 pts)

# %%
a= 180
b= a/60
print( a," minutes are", b, " hours")
# Out:
# 180  minutes are 3.0  hours

# %% [markdown]
# <b>Exercise 10</b> - Insert a markdown cell to list Objectives. (3 pts)

# %% [markdown]
# Objectives:
# <ul>
#     <li> Create a Jupyter Notebook;</li>
#     <li>Insert code and markdown cells;</li>
#     <li>Share my notebook through GitHub.</li>
# </ul>

# %% [markdown]
# <b> Exercise 11 </b> - Create a markdown cell to indicate the Author’s name. (2 pts)

# %% [markdown]
# <b>Elena Gribneva</b> <br>
# Data Scientist

# %% [markdown]
# <b> Exercise 12 </b> - Share your notebook through GitHub (3 pts)

# %% [markdown]
# <a href="https://github.com/ElGrib/Jupyter-Notebook_ElenaG">GitHub link</a>

# %% [markdown]
# <b> Exercise 13 </b> - Take a screenshot of the first page of the notebook. (1 pt)

# %% [markdown]
# ![1page.png](attachment:6b5840ca-883b-4b7b-8a31-92a801ade7d6.png)
